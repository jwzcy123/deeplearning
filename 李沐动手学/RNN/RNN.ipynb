# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 语言模型相当于n次分类模型，困惑度（perplexity）为k可以理解为k个词都有可能，越小越好

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# g表示所有层的梯度放在一起，一个向量

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 隐变量存历史信息，用过去输入和当前隐藏状态预测当前输出，用当前输入更新下一个隐藏状态
